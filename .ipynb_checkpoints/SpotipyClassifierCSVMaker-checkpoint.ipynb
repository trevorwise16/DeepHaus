# %%
import numpy as np
import pandas as pd
import keras as ks
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
##Reference Code
# louis = sp.search(q='Louis the Child', type='artist')
# louis = louis['artists']['items'][0]
# RL = sp.search(q='RL Grime', type='artist')
# RL = RL['artists']['items'][0]
# print(louis['genres'])
# print(RL['genres'])

# artist = sp.search(q='Louis the Child', limit=50, market='US', offset=0, type='track')

# tracks = artist['tracks']
# items = tracks['items']
# ids = [item['id'] for item in items]
# feats = sp.audio_features(ids)
# print(type(feats[0]))
# track = items[0]['uri']
# analysis = sp.audio_analysis(track)
# features = sp.audio_features(track)
# print(type(analysis), type(features))
# print(analysis.keys())
# print(features)
# for track in items:
#   print(track['name'])

# %% [markdown]
# # Using Spotify API Python wrapper to look at data analysis

# %% [markdown]
# ### Initialize spotipy object with client credentials

# %%
tracks = pd.DataFrame()
sp = spotipy.Spotify(client_credentials_manager=\
                     SpotifyClientCredentials(client_id='17e5b5704b914080a62aef78309e09a3', \
                                              client_secret='d9659e3b64a34faf85ae7eb71d064a51'))
# Out:
# I Wanna Know

# %% [markdown]
# This section will try and pull as much EDM data I can from Spotify to load into our dataframe

# %%
def show_recommendations_for_artist(artist):
    artists = []
    results = sp.recommendations(seed_artists = [artist['id']])
    for track in results['tracks']:
        artists.append(track['artists'][0]['name'])
    return artists

# %%
djs = ['Calvin Harris', 'Diplo', 'Louis the Child', \
       'RL Grime', 'Alison Wonderland', 'Odesza', 'Avicii', \
       'Zedd', 'Tiesto', 'Martin Garrix', 'Skrillex', 'Steve Aoki', \
       'Marshmello', 'Porter Robinson', 'The Chainsmokers', 'Kygo', \
       'Major Lazer', 'DJ Snake']
djset = set(djs)
artists = []
for dj in djs:
        artists.append(sp.search(q=dj, type='artist')['artists']['items'][0])

# %%
for a in artists:
        recs = show_recommendations_for_artist(a)
        for rec in recs:
            if rec not in djset and 'edm' in sp.search(q=rec, type='artist')['artists']['items'][0]['genres']:
                djs.append(rec)
                djset.add(rec)
# Out:
# Calvin Harris: False
# Flo Rida: True
# Zedd: True
# Martin Garrix: True
# David Guetta: True
# Calvin Harris: False
# Cash Cash: False
# Rudimental: True
# DJ Snake: True
# Cheat Codes: True
# Kygo: True
# Calvin Harris: False
# Steve Aoki: True
# Axwell /\ Ingrosso: True
# Hardwell: True
# Flo Rida: True
# Calvin Harris: False
# Felix Jaehn: True
# Martin Garrix: True
# Zedd: True
# Diplo: True
# Ekali: True
# Slushii: True
# SLANDER: True
# San Holo: True
# Diplo: True
# Ekali: True
# Flux Pavilion: True
# Smokepurpp: False
# YBN Almighty Jay: False
# Lil Xan: False
# Diplo: True
# Ekali: True
# Carnage: True
# DVBBS: True
# Dillon Francis: True
# DROELOE: True
# Diplo: True
# Lil Xan: False
# San Holo: True
# Louis The Child: False
# ODESZA: False
# BAYNK: False
# Quinn XCII: False
# Elohim: False
# Hippie Sabotage: False
# ODESZA: False
# Louis The Child: False
# Gryffin: True
# Big Gigantic: True
# Quinn XCII: False
# Louis The Child: False
# ayokay: False
# Snakehips: True
# Gryffin: True
# Chelsea Cutler: False
# Lost Kings: True
# Louis The Child: False
# ODESZA: False
# Illenium: True
# RL Grime: True
# Hippie Sabotage: False
# DROELOE: True
# What So Not: True
# GTA: True
# Rickyxsan: False
# RL Grime: True
# Ekali: True
# Dillon Francis: True
# Lookas: True
# RL Grime: True
# Virtual Self: True
# Party Favor: True
# San Holo: True
# RL Grime: True
# Jai Wolf: True
# Yellow Claw: True
# Valentino Khan: True
# San Holo: True
# RL Grime: True
# Alison Wonderland: True
# San Holo: True
# SLANDER: True
# Lookas: True
# Hippie Sabotage: False
# Alison Wonderland: True
# Illenium: True
# Ookay: True
# DROELOE: True
# Alison Wonderland: True
# Running Touch: False
# Whethan: False
# RL Grime: True
# San Holo: True
# Just A Gent: True
# Alison Wonderland: True
# Party Favor: True
# Hermitude: True
# DROELOE: True
# Alison Wonderland: True
# ODESZA: False
# RÜFÜS DU SOL: False
# San Holo: True
# What So Not: True
# Hayden James: False
# Hippie Sabotage: False
# ODESZA: False
# Porter Robinson: True
# RL Grime: True
# Seven Lions: True
# ayokay: False
# ODESZA: False
# San Holo: True
# Big Wild: False
# Illenium: True
# RÜFÜS DU SOL: False
# The Knocks: True
# ODESZA: False
# Louis The Child: False
# Kidswaste: False
# Avicii: True
# Kygo: True
# Robin Schulz: True
# Axwell /\ Ingrosso: True
# Zedd: True
# Avicii: True
# Don Diablo: True
# David Guetta: True
# Dimitri Vegas & Like Mike: True
# Avicii: True
# Kygo: True
# Vicetone: True
# Tiësto: True
# Avicii: True
# Axwell /\ Ingrosso: True
# David Guetta: True
# Afrojack: True
# Zedd: True
# Hardwell: True
# Avicii: True
# Zedd: True
# Martin Garrix: True
# Sigala: True
# DVBBS: True
# Bebe Rexha: False
# Zedd: True
# R3HAB: True
# Clean Bandit: True
# Steve Aoki: True
# Galantis: True
# Cheat Codes: True
# Zedd: True
# DJ Snake: True
# Steve Aoki: True
# Martin Garrix: True
# Cheat Codes: True
# Hardwell: True
# Zedd: True
# Hailee Steinfeld: False
# Martin Garrix: True
# Tiësto: True
# Nicky Romero: True
# R3HAB: True
# DVBBS: True
# Borgeous: True
# Tiësto: True
# Deorro: True
# Dimitri Vegas & Like Mike: True
# Don Diablo: True
# CAZZETTE: True
# Showtek: True
# Tiësto: True
# Galantis: True
# Don Diablo: True
# Steve Aoki: True
# Oliver Heldens: True
# Tiësto: True
# Otto Knows: True
# Don Diablo: True
# Galantis: True
# Martin Garrix: True
# Lost Kings: True
# KSHMR: True
# Tungevaag & Raaban: True
# Martin Garrix: True
# Vicetone: True
# Mike Williams: True
# Axwell /\ Ingrosso: True
# Robin Schulz: True
# Galantis: True
# Martin Garrix: True
# Sebastian Ingrosso: True
# Kygo: True
# Afrojack: True
# Vicetone: True
# Martin Garrix: True
# Alesso: True
# Axwell /\ Ingrosso: True
# Madison Mars: True
# R3HAB: True
# Skrillex: True
# Rezz: True
# Krewella: True
# deadmau5: True
# Slushii: True
# DVBBS: True
# Skrillex: True
# Krewella: True
# Knife Party: True
# SLANDER: True
# Dillon Francis: True
# Skrillex: True
# Slushii: True
# Porter Robinson: True
# Eptic: True
# Getter: True
# Pegboard Nerds: True
# Skrillex: True
# SLANDER: True
# Krewella: True
# Steve Aoki: True
# Dillon Francis: True
# Alesso: True
# DubVision: True
# Dimitri Vegas & Like Mike: True
# Hardwell: True
# Steve Aoki: True
# R3HAB: True
# DubVision: True
# Bassjackers: True
# Bingo Players: True
# Deorro: True
# Steve Aoki: True
# Dimitri Vegas & Like Mike: True
# Cash Cash: False
# Hardwell: True
# DVBBS: True
# Steve Aoki: True
# Quintino: True
# Sebastian Ingrosso: True
# Marshmello: True
# Sigala: True
# The Chainsmokers: True
# Borgeous: True
# Mike Perry: True
# Steve Aoki: True
# Marshmello: True
# Don Diablo: True
# The Chainsmokers: True
# Gryffin: True
# Sigala: True
# KSHMR: True
# Marshmello: True
# Galantis: True
# AREA21: True
# Matoma: True
# R3HAB: True
# Steve Aoki: True
# Marshmello: True
# Kygo: True
# Porter Robinson: True
# 3LAU: True
# Ekali: True
# Seven Lions: True
# Dillon Francis: True
# Illenium: True
# Porter Robinson: True
# deadmau5: True
# Zeds Dead: True
# Dillon Francis: True
# Slushii: True
# Porter Robinson: True
# Big Gigantic: True
# Madeon: True
# Just A Gent: True
# Virtual Self: True
# Illenium: True
# Porter Robinson: True
# Jai Wolf: True
# SLANDER: True
# The Chainsmokers: True
# DJ Snake: True
# Lauv: False
# Martin Garrix: True
# Marshmello: True
# Zedd: True
# Felix Jaehn: True
# The Chainsmokers: True
# Julia Michaels: False
# Robin Schulz: True
# Jonas Blue: True
# Don Diablo: True
# Daya: False
# The Chainsmokers: True
# Zara Larsson: True
# Clean Bandit: True
# Alan Walker: True
# The Chainsmokers: True
# DJ Snake: True
# Felix Jaehn: True
# Kygo: True
# Alan Walker: True
# Felix Jaehn: True
# Astrid S: True
# DJ Snake: True
# Martin Garrix: True
# Kygo: True
# Seeb: True
# Robin Schulz: True
# The Chainsmokers: True
# DJ Snake: True
# Sigala: True
# Kygo: True
# Syn Cole: True
# The Chainsmokers: True
# Lost Frequencies: True
# Alan Walker: True
# Gryffin: True
# Kygo: True
# The Chainsmokers: True
# Robin Schulz: True
# Major Lazer: True
# Felix Jaehn: True
# MØ: False
# Snakehips: True
# DJ Snake: True
# Don Diablo: True
# Major Lazer: True
# Steve Aoki: True
# Oliver Heldens: True
# R3HAB: True
# Zara Larsson: True
# Major Lazer: True
# Don Diablo: True
# Felix Jaehn: True
# Sean Paul: False
# Galantis: True
# Disclosure: False
# Major Lazer: True
# Flo Rida: True
# DJ Snake: True
# Martin Solveig: True
# Major Lazer: True
# Oliver Heldens: True
# R3HAB: True
# Mike Williams: True
# DJ Snake: True
# Cheat Codes: True
# Yellow Claw: True
# Kaskade: True
# R3HAB: True
# Nicky Romero: True
# DJ Snake: True
# Yellow Claw: True
# Cash Cash: False
# Don Diablo: True
# Steve Aoki: True
# Cheat Codes: True
# DJ Snake: True
# Dimitri Vegas & Like Mike: True

# %% [markdown]
# ## Now we have a good list of DJs, let's get them into a dataframe

# %% [markdown]
# First, we'll construct a list of audio feature vectors for all the songs in our DJ set

# %%
data = []
for dj in djs:
    items = sp.search(q=dj, limit=50, offset=0, market='US', type='track')['tracks']['items']
    ids = [item['id'] for item in items]
    if ids:
        ft = [np.array(list(item.values())[:11]) for item in sp.audio_features(ids) if item is not None]
        data += ft

# %% [markdown]
# Pandas conversion and saving results into a CSV for later use

# %%
npdata = np.array(data)
df = pd.DataFrame(npdata)
df.to_csv('data.csv')

# %% [markdown]
# # Now we need to get a good set of data that represents non-edm songs

# %%
nondjs = ['Beyonce', 'The Shins', 'The Who', 'Zac Brown Band', \
           'George Harrison', 'Kendrick Lamar', 'Chance the Rapper', \
           'Miley Cyrus', 'Snoop Dogg', 'Dr. Dre', 'Eminem', 'Bob Marley', \
           'Duke Ellington', 'Miles Davis', 'The Beach Boys', 'The Growlers', 'Five Seconds of Summer']
nondjset = set(nondjs)
artists2 = []
for nondj in nondjs:
    artists2.append(sp.search(q=nondj, type='artist')['artists']['items'][0])

# %%
for a in artists2:
        recs = show_recommendations_for_artist(a)
        for rec in recs:
            try:
                if rec not in nondjset and 'edm' not in sp.search(q=rec, type='artist')['artists']['items'][0]['genres']:
                    nondjs.append(rec)
                    nondjset.add(rec)
            except:
                print('oh well')
# Out:
# oh well
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'}, 'followers': {'href': None, 'total': 15799944}, 'genres': ['dance pop', 'pop', 'post-teen pop', 'r&b'], 'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m', 'id': '6vWDO969PvNqNYHIOW5v0m', 'images': [{'height': 1000, 'url': 'https://i.scdn.co/image/673cd94546df0536954198867516fee18cee1605', 'width': 1000}, {'height': 640, 'url': 'https://i.scdn.co/image/8ce3e8ae21481b60e3fb2604384b82175a949603', 'width': 640}, {'height': 200, 'url': 'https://i.scdn.co/image/ac2280a08e63bcb88f71bd3697fdc103b322ed9d', 'width': 200}, {'height': 64, 'url': 'https://i.scdn.co/image/4ad7f7740a04dee61cf4115cabbddad186def63d', 'width': 64}], 'name': 'Beyoncé', 'popularity': 87, 'type': 'artist', 'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/4LG4Bs1Gadht7TCrMytQUO'}, 'followers': {'href': None, 'total': 764900}, 'genres': ['albuquerque indie', 'alternative rock', 'chamber pop', 'folk-pop', 'garage rock', 'indie folk', 'indie pop', 'indie rock', 'indietronica', 'modern rock', 'neo-psychedelic', 'pop rock', 'stomp and holler'], 'href': 'https://api.spotify.com/v1/artists/4LG4Bs1Gadht7TCrMytQUO', 'id': '4LG4Bs1Gadht7TCrMytQUO', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/e9e850f299d7715eb1b05e07d8af3bfc98b6f9c5', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/3e473d3bf8bcbaf921082b554b0ceee47832b3cc', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/37a10c2b4cc60a984f8453c45e2984fe5840e217', 'width': 160}], 'name': 'The Shins', 'popularity': 66, 'type': 'artist', 'uri': 'spotify:artist:4LG4Bs1Gadht7TCrMytQUO'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/67ea9eGLXYMsO2eYQRui3w'}, 'followers': {'href': None, 'total': 1959792}, 'genres': ['album rock', 'art rock', 'british invasion', 'classic rock', 'folk rock', 'hard rock', 'mellow gold', 'protopunk', 'psychedelic rock', 'rock', 'roots rock'], 'href': 'https://api.spotify.com/v1/artists/67ea9eGLXYMsO2eYQRui3w', 'id': '67ea9eGLXYMsO2eYQRui3w', 'images': [{'height': 1296, 'url': 'https://i.scdn.co/image/92a5ad894b73b9e63739eb36a0500e86b2588353', 'width': 1000}, {'height': 829, 'url': 'https://i.scdn.co/image/4bc7e5ba1e9ee7610cda425ff26b33210d8f3c95', 'width': 640}, {'height': 259, 'url': 'https://i.scdn.co/image/251c72ac95f3a43b538b7e7f4221d3e7b516f7db', 'width': 200}, {'height': 83, 'url': 'https://i.scdn.co/image/fbaf3aa7b7675e0d4787237d9a9c2009091c993d', 'width': 64}], 'name': 'The Who', 'popularity': 71, 'type': 'artist', 'uri': 'spotify:artist:67ea9eGLXYMsO2eYQRui3w'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/6yJCxee7QumYr820xdIsjo'}, 'followers': {'href': None, 'total': 1174699}, 'genres': ['contemporary country', 'country', 'country road', 'modern country rock'], 'href': 'https://api.spotify.com/v1/artists/6yJCxee7QumYr820xdIsjo', 'id': '6yJCxee7QumYr820xdIsjo', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/a6d6047716a8222f95dda01f46b8ac15658d246a', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/da2bd8fc4e0f9058ff27fb680d591d8bdcf4a0ed', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/530b17b46e8be5b056ad8f6860bfd4a8a8556c6b', 'width': 160}], 'name': 'Zac Brown Band', 'popularity': 75, 'type': 'artist', 'uri': 'spotify:artist:6yJCxee7QumYr820xdIsjo'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/7FIoB5PHdrMZVC3q2HE5MS'}, 'followers': {'href': None, 'total': 855439}, 'genres': ['album rock', 'classic rock', 'folk rock', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'soft rock'], 'href': 'https://api.spotify.com/v1/artists/7FIoB5PHdrMZVC3q2HE5MS', 'id': '7FIoB5PHdrMZVC3q2HE5MS', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/8d1b36f226245c6c6d5f9fa1d020f95a5e0d3253', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/f00aa2a0bbeec665b9abe0d6b63399284e0ecf ...

# %%
data2 = []
for nondj in nondjs:
    items = sp.search(q=nondj, limit=50, offset=0, market='US', type='track')['tracks']['items']
    ids = [item['id'] for item in items]
    if ids:
        ft = [np.array(list(item.values())[:11]) for item in sp.audio_features(ids) if item is not None]
        data2 += ft

# %%
npdata2 = np.array(data2)
df2 = pd.DataFrame(npdata2)
df2.to_csv('data2.csv')

# %%
df2
# Out:
#           0       1     2       3    4       5         6         7       8   \
# 0      0.508  0.7200  11.0  -5.908  0.0  0.0628  0.272000  0.000000  0.0563
# 1      0.587  0.2990   8.0  -7.365  1.0  0.0263  0.779000  0.000000  0.1230
# 2      0.646  0.7700   2.0  -6.596  0.0  0.2260  0.002490  0.000000  0.0715
# 3      0.749  0.7170  11.0  -6.358  0.0  0.0797  0.022700  0.000000  0.2630
# 4      0.652  0.7480   0.0  -5.242  1.0  0.0887  0.084900  0.000000  0.6040
# 5      0.589  0.6210   5.0  -6.902  0.0  0.0468  0.009690  0.001040  0.1810
# 6      0.733  0.8990   0.0  -4.237  1.0  0.1430  0.004960  0.000047  0.3720
# 7      0.447  0.6940   7.0  -4.637  0.0  0.3820  0.029300  0.000005  0.1670
# 8      0.747  0.7050   9.0  -5.137  0.0  0.1260  0.012800  0.000000  0.1260
# 9      0.412  0.4410  11.0 -11.523  0.0  0.2910  0.029600  0.072600  0.3060
# 10     0.483  0.4390   9.0 -10.212  0.0  0.2380  0.805000  0.000000  0.6370
# 11     0.632  0.5180   6.0  -6.126  1.0  0.0313  0.107000  0.000000  0.3540
# 12     0.545  0.6490   6.0  -4.062  1.0  0.0324  0.143000  0.000016  0.0894
# 13     0.564  0.7030   2.0  -5.459  1.0  0.2690  0.437000  0.009270  0.3580
# 14     0.827  0.8210   3.0  -5.864  1.0  0.0419  0.007480  0.001500  0.1150
# 15     0.426  0.5840   1.0  -5.293  1.0  0.2960  0.038300  0.000000  0.1880
# 16     0.639  0.6590   8.0  -7.273  1.0  0.2150  0.241000  0.000008  0.4840
# 17     0.665  0.7870   5.0  -5.730  1.0  0.1510  0.308000  0.000000  0.2190
# 18     0.750  0.4580   1.0  -9.092  1.0  0.0803  0.226000  0.000032  0.1370
# 19     0.573  0.5910  11.0  -6.715  0.0  0.3310  0.010700  0.000000  0.4550
# 20     0.616  0.7800   2.0  -6.062  1.0  0.0623  0.032200  0.000000  0.1730
# 21     0.470  0.7920   0.0  -8.932  1.0  0.2600  0.171000  0.000001  0.3130
# 22     0.768  0.8070   2.0  -5.508  0.0  0.1060  0.053000  0.000003  0.2140
# 23     0.723  0.6330   9.0  -5.615  0.0  0.0571  0.319000  0.000000  0.1220
# 24     0.576  0.6970  10.0  -4.192  1.0  0.3260  0.028600  0.000001  0.1670
# 25     0.412  0.4410  11.0 -11.523  0.0  0.2910  0.029600  0.072600  0.3060
# 26     0.655  0.4880   1.0  -9.170  1.0  0.2200  0.082500  0.000001  0.2210
# 27     0.711  0.8110   6.0  -7.503  0.0  0.2190  0.032800  0.000517  0.0649
# 28     0.632  0.5180   6.0  -6.126  1.0  0.0313  0.107000  0.000000  0.3540
# 29     0.512  0.6250  11.0  -6.764  1.0  0.0508  0.003080  0.000164  0.3460
# ...      ...     ...   ...     ...  ...     ...       ...       ...     ...
# 12074  0.415  0.2630   2.0 -16.541  1.0  0.0928  0.411000  0.003060  0.3420
# 12075  0.591  0.4020   1.0  -5.847  0.0  0.0337  0.192000  0.000000  0.1480
# 12076  0.390  0.5360   6.0  -7.536  0.0  0.0384  0.593000  0.000000  0.1150
# 12077  0.726  0.6180   0.0  -4.843  1.0  0.1230  0.059500  0.000044  0.1510
# 12078  0.669  0.5630   7.0  -8.370  1.0  0.0334  0.269000  0.000000  0.1140
# 12079  0.518  0.7250   8.0  -7.492  1.0  0.1290  0.075100  0.000024  0.0900
# 12080  0.625  0.7160   0.0  -6.480  1.0  0.0498  0.063000  0.000000  0.1350
# 12081  0.491  0.6220   8.0  -5.925  1.0  0.1040  0.019000  0.000000  0.1070
# 12082  0.605  0.5950   4.0  -7.186  0.0  0.0442  0.000851  0.000002  0.1140
# 12083  0.481  0.1790   3.0 -21.424  1.0  0.1090  0.613000  0.000028  0.1450
# 12084  0.560  0.8890  11.0  -5.148  1.0  0.0493  0.047700  0.000063  0.2680
# 12085  0.631  0.8530   0.0  -5.925  1.0  0.0565  0.009510  0.000000  0.0713
# 12086  0.727  0.8320  10.0  -6.037  1.0  0.0843  0.134000  0.000005  0.3840
# 12087  0.378  0.6090   7.0  -5.985  0.0  0.0971  0.022100  0.001060  0.0652
# 12088  0.326  0.5690   2.0  -5.953  0.0  0.0444  0.149000  0.000000  0.1860
# 12089  0.647  0.9200   5.0  -4.556  0.0  0.0410  0.046000  0.005800  0.3570
# 12090  0.506  0.5880   3.0  -7.711  0.0  0.0452  0.011400  0.000769  0.1250
# 12091  0.496  0.4090   0.0 -10.495  1.0  0.0659  0.352000  0.000000  0.1200
# 12092  0.637  0.7950   0.0  -6.691  1.0  0.0673  0.120000  0.000003  0.1660
# 12093  0.419  0.4960  10.0  -9.222  1.0  0.0826  0.136000  0.000000  0.2910
# 12094  0.539  0.2980   1.0  -5.915  1.0  0.0377  0.922000  0.000030  0.0974
# 12095  0.559  0.6700   4.0  -6.301  0.0  0.0404  0.082300  0.017100  0.1060
# 12096  0.579  0.6060   5.0  -8.405  0.0  0.1840  0.002960  0.000031  0.0669
# 12097  0.650  0.8870  10.0  -3.517  0.0  0.0365  0.065100  0.000344  0.2820
# 12098  0.492  0.1790   4.0 -17.106  0.0  0.0630  0.372000  0.001880  0.1010
# 12099  0.515  0.8060   1.0  -4.709  1.0  0.0891  0.025500  0.000003  0.4780
# 12100  0.471  0.0410   9.0 -19.879  0.0  0.0337  0.816000  0.000314  0.1080
# 12101  0.461  0.0622  10.0 -20.557  0.0  0.0464  0.897000  0.000218  0.1110
# 12102  0.525  0.8410  10.0  -2.849  1.0  0.0340  0.056000  0.000000  0.1240
# 12103  0.541  0.1860   7.0 -11.321  1.0  0.0311  0.958000  0.000000  0.0962
#
#            9        10
# 0      0.4720   79.983
# 1      0.3560   94.992
# 2      0.6810   99.165
# 3      0.4000  104.967
# 4      0.6520   94.100
# 5      0.4010  140.030
# 6      0.7600  127.086
# 7      0.5090  175.868
# 8      0.5600  136.024
# 9      0.1740  185.571
# 10     0.6180   81.986
# 11     0.4270   90.007
# 12     0.2970   99.099
# 13     0.4770  139.045
# 14     0.6840  122.017
# 15     0.2720  193.437
# 16     0.4570  136.801
# 17     0.6990  167.349
# 18     0.5360   83.610
# 19     0.2320   86.721
# 20     0.4710  110.005
# 21     0.2140  170.085
# 22     0.5750  112.001
# 23     0.5030  138.071
# 24     0.5010  175.906
# 25     0.1740  185.571
# 26     0.7910   91.025
# 27     0.7850  117.999
# 28     0.4270   90.007
# 29     0.2010  129.935
# ...       ...      ...
# 12074  0.3110  165.770
# 12075  0.0678  125.015
# 12076  0.2120  129.997
# 12077  0.9230  161.962
# 12078  0.4870  130.010
# 12079  0.3280  144.032
# 12080  0.5380   94.986
# 12081  0.3610   77.928
# 12082  0.0386   92.094
# 12083  0.4050   74.850
# 12084  0.4580  105.989
# 12085  0.4050  103.985
# 12086  0.6080  108.028
# 12087  0.0788   87.456
# 12088  0.1650  148.658
# 12089  0.2420  125.997
# 12090  0.2690   78.158
# 12091  0.7000   85.332
# 12092  0.5410  156.012
# 12093  0.3890   90.012
# 12094  0.2740  126.679
# 12095  0.3380  104.004
# 12096  0.2350  160.046
# 12097  0.3430  108.026
# 12098  0.4300  199.148
# 12099  0.3530  122.114
# 12100  0.2910   80.690
# 12101  0.1150  134.445
# 12102  0.3280   99.973
# 12103  0.1620   92.544
#
# [12104 rows x 11 columns]
